# %%
import lightgbm as lgb
import pandas as pd

# %%
data = pd.read_csv('./data/data_pre.csv')

# %%
test = pd.read_csv('./data/test_pre.csv')

# %%
def_cols = ['OrderID', 'Interval', 'ChannelID', 'Cluster', 'DeliveryType', 'prepay', 'count_edit', 'OrderCnt', 'OrderDate_weekday', 'Date_weekday', 'GroupID_12.0']

# %%
cols = data.columns[data.columns.isin(test.columns)]

# %%
test = test[def_cols]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-dc650adb2dc2> in <module>
# ----> 1 test = test[def_cols]
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
# ...

# %%
bst = lgb.Booster(model_file='model.txt')

# %%
pred = bst.predict(test.drop('OrderID', axis=1))

# %%
test['Score'] = pred

# %%
#df['Score'] = df['Score'].apply(lambda x: round(x, 2))

# %%
test['ID'] = test['OrderID'].apply(lambda x: str(x)+' ')

# %%
test[['ID', 'Score']].to_csv('res_.csv', index=False, encoding='windows-1251')

# %%
pd.read_csv('res_.csv')
# Out:
#                  ID     Score
# 0       90102211131  0.269699
# 1       90102211133  0.050998
# 2       90102216055  0.225347
# 3       90102216081  0.297398
# 4       90102216084  0.265215
# ...             ...       ...
# 202609  98359057260  0.088326
# 202610  98359057293  0.117402
# 202611  98359057392  0.096682
# 202612  98359057487  0.033321
# 202613  98359057507  0.027552
#
# [202614 rows x 2 columns]
